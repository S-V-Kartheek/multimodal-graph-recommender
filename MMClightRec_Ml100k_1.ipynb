# %% [markdown]
# <a href="https://colab.research.google.com/github/S-V-Kartheek/multimodal-graph-recommender/blob/main/MMClightRec_Ml100k_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Wed Mar 25 03:48:39 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# Copy the zip from Drive to Colab's faster local storage
# !cp "/content/drive/MyDrive/MGRS_ClightRec.zip" "/content/"

# Unzip it
# !unzip -q "/content/MGRS_ClightRec.zip" -d "/content/MGRS_ClightRec"

# Move into the project directory
# %cd /content/MGRS_ClightRec
# Out:
# ...
# /content/MGRS_ClightRec

# %%
import torch

# Get the exact Torch and CUDA versions running on the Colab T4 instance
torch_ver = torch.__version__.split('+')[0]
cuda_ver = torch.version.cuda.replace('.', '')
wheel_url = f"https://data.pyg.org/whl/torch-{torch_ver}+cu{cuda_ver}.html"

# Write a quick script to run pip with the wheels URL so nothing builds from source!
get_ipython().system(f'pip install -r requirements.txt -f {wheel_url}')
# Out:
# Looking in links: https://data.pyg.org/whl/torch-2.10.0+cu128.html
# ...
#   Using cached torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 94.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 98.3 MB/s eta 0:00:00
# ...
# Using cached torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
# ...

# %%
# !python main.py --dataset ml100k --include_cold_start
# Out:
# ...
#   MM-CLightRec: Contrastive Multimodal LightGCN Recommendation
#   Dataset: ml100k
# L3 Cold-Start Active  : Yes
#   Version: JOURNAL (with L3 cold-start)
# ...
#
# [STEP 1] Loading and preprocessing ml100k dataset...
# [INFO] ML-100K loaded: users=943, items=1682, interactions=100000
# [INFO] Split: train=79619, val=9596, test=10785
# [INFO] Data loading completed in 0.7 seconds
# [INFO] Users: 943, Items: 1682
# [INFO] User features: torch.Size([943, 202])
# [INFO] Item features: torch.Size([1682, 202])
# [INFO] Per-modality dimensions: {'text': 100, 'image': 64, 'video': 20, 'meta': 18}
# [INFO] Total interactions: 100000
# [INFO] Train/Val/Test: 79619/9596/10785
#
# [STEP 2] Training MM-CLightRec model for 120 epochs...
# [INFO] Using device: cuda
# [INFO] Feature dim: 202, Users: 943, Items: 1682
# [INFO] Modality dims: {'text': 100, 'image': 64, 'video': 20, 'meta': 18}
# [INFO] Total parameters:     338,856
# [INFO] Trainable parameters: 338,856
# ...

# %%
# !unzip /content/MGRS_ClightRec_Colab.zip
# Out:
# Archive:  /content/MGRS_ClightRec_Colab.zip
# ...
# replace colab/MGRS_HFA_Train.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: colab/MGRS_HFA_Train.py
# replace colab/MM_CLightRec_ML1M.ipynb? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: colab/MM_CLightRec_ML1M.ipynb
# replace colab/README.md? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: colab/README.md
# replace data/ml-100k/allbut.pl? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: data/ml-100k/allbut.pl
#   inflating: data/ml-100k/mku.sh
#   inflating: data/ml-100k/README
#   inflating: data/ml-100k/u.data
#   inflating: data/ml-100k/u.genre
#   inflating: data/ml-100k/u.info
#   inflating: data/ml-100k/u.item
#   inflating: data/ml-100k/u.occupation
#   inflating: data/ml-100k/u.user
#   inflating: data/ml-100k/u1.base
#   inflating: data/ml-100k/u1.test
#   inflating: data/ml-100k/u2.base
#   inflating: data/ml-100k/u2.test
#   inflating: data/ml-100k/u3.base
#   inflating: data/ml-100k/u3.test
# ...

# %%
# !python evaluate_sampled.py
# Out:
# ...
#    MGAT / MGRS-HFA Sample-Based Evaluation Protocol
# ...
# [INFO] ML-100K loaded: users=943, items=1682, interactions=100000
# [INFO] Split: train=79619, val=9596, test=10785
# [INFO] Loading trained model from results/mm_clightrec_ml100k.pth...
#
# [INFO] Building K-Means cluster graph (runs once)...
# [CBF] Running K-means: 20 user clusters, 15 item clusters...
#
# [INFO] Starting Sampled Evaluation (1000 negatives per user)....
# [INFO] Computing ranking for 943 users...
# [INFO] Evaluated 909 users in 0.14s
#
# ...
#  REPORTED METRICS FOR YOUR CONFERENCE TABLE
#  (Comparable 1:1 against MGRS-HFA baseline printed numbers)
# ...
#   Sampled HitRatio@10 : 0.6128
#   Sampled NDCG@10     : 0.1933
#   Sampled Recall@10   : 0.1647
#   Sampled Precision@10: 0.1466
#   Sampled F1-Score@10 : 0.1311
# ...

# %%
# Create a folder in your Drive for the results
# !mkdir -p "/content/drive/MyDrive/ML100K_Results"

# Copy the entire results folder over
# !cp -r /content/MGRS_ClightRec/results/* "/content/drive/MyDrive/ML100K_Results/"

print("✅ Training results successfully backed up to Google Drive!")
# Out:
# ✅ Training results successfully backed up to Google Drive!
